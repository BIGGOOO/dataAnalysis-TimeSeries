# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt
import warnings

warnings.filterwarnings("ignore")

# %%
data_2019 = pd.read_csv('2019.csv')
data_2020 = pd.read_csv('2020.csv')
data_2021 = pd.read_csv('2021.csv')
data_2022 = pd.read_csv('2022.csv')
data_2023 = pd.read_csv('2023.csv')

# %%
# Concatenate all years' data into one DataFrame
all_data = pd.concat([data_2019, data_2020, data_2021, data_2022])

# Data preprocessing: Remove null values and set index
all_data.dropna(inplace=True)
all_data.set_index(['Província', 'Distrito'], inplace=True)

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 159 entries, ('Niassa', 'Lago') to ('Nampula', 'Mogovolas')
# Data columns (total 53 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W1      159 non-null    int64
#  1   W2      159 non-null    int64
#  2   W3      159 non-null    int64
#  3   W4      159 non-null    int64
#  4   W5      159 non-null    int64
#  5   W6      159 non-null    int64
#  6   W7      159 non-null    int64
#  7   W8      159 non-null    int64
#  8   W9      159 non-null    int64
#  9   W10     159 non-null    int64
#  10  W11     159 non-null    int64
#  11  W12     159 non-null    float64
#  12  W13     159 non-null    int64
#  13  W14     159 non-null    int64
#  14  W15     159 non-null    int64
#  15  W16     159 non-null    int64
#  16  W17     159 non-null    int64
#  17  W18     159 non-null    int64
#  18  W19     159 non-null    int64
#  19  W20     159 non-null    int64
#  20  W21     159 non-null    int64
#  21  W22     159 non-null    int64
#  22  W23     159 non-null    int64
#  23  W24     159 non-null    int64
#  24  W25     159 non-null    int64
#  25  W26     159 non-null    int64
#  26  W27     159 non-null    int64
#  27  W28     159 non-null    int64
#  28  W29     159 non-null    int64
#  29  W30     159 non-null    int64
#  30  W31     159 non-null    int64
#  31  W32     159 non-null    int64
#  32  W33     159 non-null    int64
#  33  W34     159 non-null    int64
#  34  W35     159 non-null    int64
#  35  W36     159 non-null    int64
#  36  W37     159 non-null    int64
#  37  W38     159 non-null    int64
#  38  W39     159 non-null    int64
#  39  W40     159 non-null    int64
#  40  W41     159 non-null    int64
#  41  W42     159 non-null    int64
#  42  W43     159 non-null    int64
#  43  W44     159 non-null    int64
#  44  W45     159 non-null    int64
#  45  W46     159 non-null    int64
#  46  W47     159 non-null    int64
#  47  W48     159 non-null    int64
#  48  W49     159 non-null    int64
#  49  W50     159 non-null    int64
#  50  W51     159 non-null    int64
#  51  W52     159 non-null    int64
#  52  W53     159 non-null    float64
# dtypes: float64(2), int64(51)
# memory usage: 69.3+ KB

# %%
# Function to evaluate ARIMA model on a given province and district
def evaluate_arima_model(train_data, test_data):
    # Define the model
    model = ARIMA(train_data, order=(5,1,0))
    # Fit the model
    model_fit = model.fit()
    # Make predictions
    predictions = model_fit.forecast(steps=len(test_data))[0]
    # Calculate RMSE
    rmse = sqrt(mean_squared_error(test_data, predictions))
    return rmse

# %%
# Iterate over each province and district to train and test ARIMA model
total_rmse = 0
num_records = 0
for (province, district), group in all_data.groupby(level=[0, 1]):
    # Aggregate the data by taking the mean across the weeks
    train_data_aggregated = group.iloc[:, 2:-1].mean(axis=1)  # Exclude the first two columns (Province and District)
    test_data_aggregated = group.iloc[:, -1]

    # Convert to univariate time series (pandas Series)
    train_data_aggregated = train_data_aggregated.squeeze()
    test_data_aggregated = test_data_aggregated.squeeze()

    try:
        # Evaluate ARIMA model
        rmse = evaluate_arima_model(train_data_aggregated, test_data_aggregated)
        print(f'Province: {province}, District: {district}, RMSE: {rmse}')
        
        total_rmse += rmse
        num_records += 1
    except Exception as e:
        print(f"Error occurred for Province: {province}, District: {district}: {str(e)}")
# Out:
# Error occurred for Province: Cabo Delgado, District: Ancuabe: too many indices for array
# Error occurred for Province: Cabo Delgado, District: Chiure: too many indices for array
# Error occurred for Province: Cabo Delgado, District: Ibo: too many indices for array
# Error occurred for Province: Cabo Delgado, District: Macomia: object of type 'numpy.float64' has no len()
# Error occurred for Province: Cabo Delgado, District: Mecufi: object of type 'numpy.float64' has no len()
# Error occurred for Province: Cabo Delgado, District: Meluco: too many indices for array
# Error occurred for Province: Cabo Delgado, District: Metuge: too many indices for array
# Error occurred for Province: Cabo Delgado, District: Mocimboa da Praia: too many indices for array
# Error occurred for Province: Cabo Delgado, District: Montepuez: too many indices for array
# Error occurred for Province: Cabo Delgado, District: Mueda: object of type 'numpy.float64' has no len()
# Error occurred for Province: Cabo Delgado, District: Namuno: too many indices for array
# Error occurred for Province: Cabo Delgado, District: Pemba: too many indices for array
# Error occurred for Province: Gaza, District: Massingir*: too many indices for array
# Error occurred for Province: Gaza, District: Xai-Xai*: too many indices for array
# Error occurred for Province: Inhambane, District: Govuro: too many indices for array
# Error occurred for Province: Manica, District: Chimoio: too many indices for array
# Error occurred for Province: Manica, District: Gondola: too many indices for array
# Error occurred for Province: Manica, District: Macati: too many indices for array
# Error occurred for Province: Manica, District: Manica: too many indices for array
# Error occurred for Province: Manica, District: Tambara: too many indices for array
# Error occurred for Province: Manica, District: Vanduzi: too many indices for array
# Error occurred for Province: Nampula, District: Cidade de Nampula: too many indices for array
# Error occurred for Province: Nampula, District: Erati: too many indices for array
# Error occurred for Province: Nampula, District: Meconta: too many indices for array
# Error occurred for Province: Nampula, District: Memba: too many indices for array
# Error occurred for Province: Nampula, District: Mogovolas: too many indices for array
# Error occurred for Province: Nampula, District: Moma: too many indices for array
# Error occurred for Province: Nampula, District: Monapo: too many indices for array
# Error occurred for Province: Nampula, District: Nacala Porto: too many indices for array
# Error occurred for Province: Nampula, District: Nacala Velha: too many indices for array
# Error occurred for Province: Nampula, District: Nacaroa: too many indices for array
# Error occurred for Province: Nampula, District: Ribaue: too many indices for array
# Error occurred for Province: Niassa, District: Chimbunila: too many indices for array
# Error occurred for Province: Niassa, District: Lago: too many indices for array
# Error occurred for Province: Niassa, District: Lichinga: too many indices for array
# Error occurred for Province: Niassa, District: Majune: too many indices for array
# Error occurred for Province: Niassa, District: Mandimba*: too many indices for array
# Error occurred for Province: Niassa, District: Marrupa: too many indices for array
# Error occurred for Province: Niassa, District: Mavago: too many indices for array
# Error occurred for Province: Niassa, District: Mecanhelas: too many indices for array
# Error occurred for Province: Niassa, District: Muembe*: too many indices for array
# Error occurred for Province: Niassa, District: Ngauma*: too many indices for array
# Error occurred for Province: Niassa, District: Sanga: too many indices for array
# Error occurred for Province: Sofala, District: Beira: too many indices for array
# Error occurred for Province: Sofala, District: Búzi*: too many indices for array
# Error occurred for Province: Sofala, District: Caia: too many indices for array
# Error occurred for Province: Sofala, District: Chemba: too many indices for array
# Error occurred for Province: Sofala, District: Cheringoma: too many indices for array
# Error occurred for Province: Sofala, District: Chibabava: too many indices for array
# Error occurred for Province: Sofala, District: Dondo: too many indices for array
# Error occurred for Province: Sofala, District: Gorongoza: too many indices for array
# Error occurred for Province: Sofala, District: Machanga: too many indices for array
# Error occurred for Province: Sofala, District: Maringue: too many indices for array
# Error occurred for Province: Sofala, District: Marromeu: too many indices for array
# Error occurred for Province: Sofala, District: Muanza: too many indices for array
# Error occurred for Province: Sofala, District: Nhamatanda: too many indices for array
# Error occurred for Province: Tete, District: Angónia: too many indices for array
# Error occurred for Province: Tete, District: Cahora Bassa: too many indices for array
# Error occurred for Province: Tete, District: Chifunde: too many indices for array
# Error occurred for Province: Tete, District: Chiúta: too many indices for array
# Error occurred for Province: Tete, District: Cidade de Tete: too many indices for array
# Error occurred for Province: Tete, District: Doa: too many indices for array
# Error occurred for Province: Tete, District: Macanga: too many indices for array
# Error occurred for Province: Tete, District: Magoe: too many indices for array
# Error occurred for Province: Tete, District: Marara: too many indices for array
# Error occurred for Province: Tete, District: Maravia: too many indices for array
# Error occurred for Province: Tete, District: Moatize: too many indices for array
# Error occurred for Province: Tete, District: Mutarara: too many indices for array
# Error occurred for Province: Tete, District: Tsangano: too many indices for array
# Error occurred for Province: Tete, District: Zumbo: too many indices for array
# Error occurred for Province: Zambézia, District: Gile: too many indices for array
# Error occurred for Province: Zambézia, District: Gurue: too many indices for array
# Error occurred for Province: Zambézia, District: Inhassunge: too many indices for array
# Error occurred for Province: Zambézia, District: Maganja da Costa: too many indices for array
# Error occurred for Province: Zambézia, District: Milange*: too many indices for array
# Error occurred for Province: Zambézia, District: Mocuba: too many indices for array
# Error occurred for Province: Zambézia, District: Mopeia: too many indices for array
# Error occurred for Province: Zambézia, District: Morrumbala: too many indices for array
# Error occurred for Province: Zambézia, District: Namacurra: too many indices for array
# Error occurred for Province: Zambézia, District: Nicoadala: too many indices for array
# Error occurred for Province: Zambézia, District: Quelimane: too many indices for array
